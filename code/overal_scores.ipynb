# %%
from string import Template
import time

xval_key='Chrono'
comp_key='Multi'
metric='len'
figsize = (4, 4)
figsize = (6, 3)
perf_scores = ['test_auc','test_pearson']
var_param = ['fc','fwidth']

latex_temp = Template('\\includegraphics[width=\\rSearchwidth\\textwidth]{../code/output/$fname}')

with open('output/latex_rSearch_snippet','w') as f:
    now = time.strftime("%c")
    f.write('Generated on %s\n'  % now )
    
    
for VP in ['VPpcac','VPpcad','VPpcae']:
    print('########## %s ##########' % VP)
    days = ['d0','d4'] if VP == 'VPpcae' else ['d0','d2','d3','d4']
    for day in days:
        print('--- %s ---' % day)
        # %run -i /home/jscastanoc/Dropbox/Solo/work/research/STUPS_analysis/ward_analysisOverview/overall/analysis_doublePar.py
        print('saving figs')
        plt.show()
        for key_fig, fig in all_figs.items():
            fname = 'output/rSearch_{}_{}_{}_{}.pdf'.format(VP,day,metric,key_fig)
            fig.savefig(fname)        
            with open('output/latex_rSearch_snippet','a') as f:
                line=latex_temp.substitute(fname=fname)
                f.write(line+'\n')
# Out:
# ########## VPpcac ##########
# --- d0 ---
# saving figs
# --- d2 ---
# saving figs
# --- d3 ---
# saving figs
# --- d4 ---
# saving figs
# ########## VPpcad ##########
# --- d0 ---
# saving figs
# --- d2 ---
# saving figs
# --- d3 ---
# saving figs
# --- d4 ---
# saving figs
# ########## VPpcae ##########
# --- d0 ---
# saving figs
# --- d4 ---
# saving figs
